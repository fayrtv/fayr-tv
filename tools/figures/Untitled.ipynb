# %%
# !ls
# !pwd
# Out:
# Pipfile                Untitled.ipynb         licenses.json
# Pipfile.lock           amount_attendees.ipynb results.csv
# /Users/tinvotan/Projects/fayrtv/fayr_tv_live/packages/fayr-figures

# %%
import pandas as pd

# %%
df = pd.read_json('licenses.json')
print(df)
# Out:
#                                          2-thenable@1.0.0  \
# licenses                                              ISC
# repository          https://github.com/medikoo/2-thenable
# publisher                                   Mariusz Nowak
# email                                   medyk@medikoo.com
# url                               http://www.medikoo.com/
# path                 fayr_tv_live/node_modules/2-thenable
# licenseFile  fayr_tv_live/node_modules/2-thenable/LICENSE
# noticeFile                                            NaN
#
#                                    @ampproject/remapping@2.1.2  \
# licenses                                            Apache-2.0
# repository             https://github.com/ampproject/remapping
# publisher                                     Justin Ridgewell
# email                                    jridgewell@google.com
# url                                                        NaN
# ...

# %%
df.describe()
# Out:
#        2-thenable@1.0.0 @ampproject/remapping@2.1.2  \
# count                 7                           6
# unique                7                           6
# top       Mariusz Nowak                  Apache-2.0
# freq                  1                           1
#
#        @apideck/better-ajv-errors@0.3.3 @aws-crypto/ie11-detection@2.0.0  \
# count                                 7                                7
# unique                                7                                7
# top                                 MIT            AWS Crypto Tools Team
# freq                                  1                                1
#
#        @aws-crypto/sha256-browser@2.0.0 @aws-crypto/sha256-js@2.0.0  \
# count                                 7                           7
# unique                                7                           7
# top               AWS Crypto Tools Team       AWS Crypto Tools Team
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, licenses to noticeFile
# Columns: 2547 entries, 2-thenable@1.0.0 to zip-stream@4.1.0
# dtypes: object(2547)
# memory usage: 159.2+ KB
